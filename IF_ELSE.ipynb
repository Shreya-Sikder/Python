# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreya-Sikder/Python/blob/main/IF_ELSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conditional Statement

# %%
x=int(input("Enter your value1:"))
y=int(input("Enter your value2:"))
if x<y:
  print("hello")
else:
  print("goodbye")
# Out:
# Enter your value1:45
# Enter your value2:78
# hello

# %%
a,b=20,5
if a>b:
  print("A is the bigger one")
  if a<10:
    print("A has a small value")
  else:
    print("A is  greater than 10")
else:
  print("B for boss")
# Out:
# A is the bigger one
# A is  greater than 10
