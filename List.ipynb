# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreya-Sikder/Python/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create lists with different datatype

# %%
mylist=["S",24,"U"]
print(mylist)
# Out:
# ['S', 24, 'U']

# %% [markdown]
# Access values from list

# %%
mylist=["s",23,7.9,"4"]
print(mylist[0],type(mylist[2]))
# Out:
# s <class 'float'>

# %% [markdown]
# Update List Values

# %%
mylist=[2,3,5,6,7]
mylist[2]="Hi"
print(mylist)
# Out:
# [2, 3, 'Hi', 6, 7]

# %% [markdown]
# Remove elements from a list

# %%
mylist=[2,3,5,6,7]
del mylist[2]
print(mylist)
# Out:
# [2, 3, 6, 7]

# %% [markdown]
# Removing element from a list  by remove method

# %%
mylist=[12,3,15,16,27]
mylist.remove(3)
print(mylist)
# Out:
# [12, 15, 16, 27]

# %% [markdown]
# Delete whole list

# %%
mylist = [12, 3, 15, 16, 27]
mylist.clear()

if len(mylist) == 0:
    print("Empty")
else:
    print("Exist")
# Out:
# Empty

# %% [markdown]
# Sum of Elements

# %%
mylist=[2,5,78,99,46]
print(sum(mylist))
# Out:
# 230

# %% [markdown]
# Maximum and Minimum

# %%
#way1
mylist=[2,0.5,78,9.9,46]
mylist=sorted(mylist)
print(mylist[0])
print(mylist[4])
# Out:
# 0.5
# 78

# %%
#way2
mylist=[2,0.5,78,9.9,46]
list.sort(mylist)
print(mylist[0])
print(mylist[4])
# Out:
# 0.5
# 78

# %% [markdown]
# Reverse a List

# %%
#way1
mylist=[2,0.5,78,9.9,46]
mylist=list(reversed(mylist))
print(mylist)
# Out:
# [46, 9.9, 78, 0.5, 2]

# %%
#way2
mylist=[2,0.5,78,9.9,46]
list.reverse(mylist)
print(mylist)
# Out:
# [46, 9.9, 78, 0.5, 2]

# %% [markdown]
# Count Occurrences

# %%
mylist=[1,4,2,1,2,3,4,6,1,2,3,4]
x=input("Enter number to count:")
print(mylist.count(int(x))) #mention the datatype because input returns string
# Out:
# Enter number to count:1
# 0

# %% [markdown]
# Remove Duplicates

# %%
#way1
mylist=[1,4,2,1,2,3,4,6,1,2,3,4]
mylist=list(dict.fromkeys(mylist))
print(mylist)
# Out:
# [1, 4, 2, 3, 6]

# %%
#way2
mylist=[1,4,2,1,2,3,4,6,1,2,3,4]
new=[]
for item in mylist:
  if item not in new:
    new.append(item)

print(new)
new=sorted(new)
print("sorted:",new)
# Out:
# [1, 4, 2, 3, 6]
# sorted: [1, 2, 3, 4, 6]

# %% [markdown]
# Second Largest Number

# %%
mylist=[23,90,1,3,8,34,9,15]
mylist=sorted(mylist)
mylist.reverse()
print(mylist[1])
# Out:
# 34

# %% [markdown]
# Even and Odd Separation

# %%
mylist=[23,90,1,3,8,34,9,15,70,24,18]
mylist=sorted(mylist)
odd=[]
even=[]
for item in mylist:
  if item%2==0:
    even.append(item)
  else:
    odd.append(item)

print("even list:", even)
print("odd list:", odd)
# Out:
# even list: [8, 18, 24, 34, 70, 90]
# odd list: [1, 3, 9, 15, 23]

# %% [markdown]
# List Rotation

# %%
mylist = [1,2,3,4,5]
k = 2
k= k% len(mylist)
mylist=mylist[-k:]+mylist[:-k]
print(mylist)
# Out:
# [4, 5, 1, 2, 3]
