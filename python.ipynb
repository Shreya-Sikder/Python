# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreya-Sikder/Python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BASICS OF PYTHON

# %% [markdown]
# Variable & Datatype

# %%
a="shreya"
b="2003"
print(a+b)
# Out:
# shreya2003

# %%
a=str(100)
print(a+a)
# Out:
# 100100

# %%
s="shreya"
print(s, type(s))
# Out:
# shreya <class 'str'>

# %%
a=12
print(type(a))
# Out:
# <class 'int'>

# %%
print("Hello World")
# Out:
# Hello World
