# %%
import numpy as np

# %%
a=np.array([1,8,9])
print(a)
# Out:
# [1 8 9]

# %%
b=np.array([[1,2,3],[2,6,7]])
print(b)
# Out:
# [[1 2 3]
#  [2 6 7]]

# %% [markdown]
# Get Dimension

# %%
b.ndim
# Out:
# 2

# %% [markdown]
# Get Shape

# %%
b.shape
# Out:
# (2, 3)

# %% [markdown]
# Reshape

# %%
b.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 2],
#        [6, 7]])

# %% [markdown]
# Get type

# %%
a.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Size

# %%
a.itemsize
b.itemsize
# Out:
# 8
