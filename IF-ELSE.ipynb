# %% [markdown]
# Conditional Statement

# %%
x=input("Enter your value1:")
y=input("Enter your value2:")
if x<y:
  print("hello")
else:
  print("goodbye")
# Out:
# Enter your value1:23
# Enter your value2:45
# hello

# %%
a,b=20,5
if a>b:
  print("A is the bigger one")
  if a<10:
    print("A has a small value")
  else:
    print("A is  greater than 10")
else:
  print("B for boss")
# Out:
# A is the bigger one
# A is  greater than 10
